# %%
#import dependencies
import pandas as pd
import numpy as np
import random as rn
import gym
from keras import backend as K
from keras.models import Sequential
from keras.optimizers import RMSprop
from keras.layers import Conv2D, Dense, Flatten, BatchNormalization
import tensorflow as tf
from tensorflow.losses import huber_loss
import os
from keras.utils import plot_model
from IPython.display import Image
from matplotlib import pyplot as plt
import seaborn as sns


# Add graphviz to PATH environmental variable (for NN model architecture visualizations)
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

# Set randomization defaults for solution reproducability
np.random.seed(21)
rn.seed(21)
tf.set_random_seed(21)

# Set conditions for keras result reproducability
session_conf = tf.ConfigProto(intra_op_parallelism_threads = 1, inter_op_parallelism_threads = 1)
sess = tf.Session(graph = tf.get_default_graph(), config = session_conf)
K.set_session(sess)

# Set visualization defaults
sns.set_context('notebook')


# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
env = gym.make('SpaceInvaders-v0')

obs = env.reset()

print(obs.shape)
print(env.action_space)
# Out:
# (210, 160, 3)
# Discrete(6)

# %%
def process_image(obs):
    img = obs[8:195:2, ::2]
    img = (img.mean(axis = 2) - 128) # convert to greyscale, center to [-128, 128]
    img = img.astype(np.uint8)  # cast as integers
    img = img.reshape((1,) + img.shape + (1,)) # reshape to 1 x H x L x 1 for Keras compatibility
    return img # return 3D numpy array

# %%
img = process_image(obs)

fig = plt.figure()
ax = fig.add_subplot(111)

ax.axis("off")
plt.imshow(img.reshape(img.shape[1], img.shape[2]))

img_shape = img.shape

print('Processed Image Dimension: {:} x {:} x {:} x {:}'.format(img_shape[0], img_shape[1], img_shape[2], img_shape[3]))
# Out:
# Processed Image Dimension: 1 x 94 x 80 x 1

# %%
class ReplayMemory:
    def __init__(self, maxlen):
        self.maxlen = maxlen
        self.buf = np.empty(shape = maxlen, dtype = np.object)
        self.index = 0
        self.length = 0
        
    def append(self, data):
        self.buf[self.index] = data
        self.length = min(self.length + 1, self.maxlen)
        self.index = (self.index + 1) % self.maxlen
    
    def sample(self, batch_size, with_replacement = True):
        if with_replacement:
            indices = np.random.randint(self.length, size = batch_size)
        else:
            indices = np.random.permutation(self.length)[:batch_size]
        return self.buf[indices]

# %%
def sample_memories(memory_store, batch_size):
    cols = [[], [], [], [], []] # state, action, reward, next_state, continue
    for memory in memory_store.sample(batch_size):
        for col, value in zip(cols, memory):
            col.append(value)
    cols = [np.array(col) for col in cols]
    return cols[0], cols[1], cols[2].reshape(-1, 1), cols[3], cols[4].reshape(-1, 1)

class DDQNAgent:
    def __init__(self, image_shape, action_space, learning_rate, rho, optimizer_epsilon, replay_memory, gamma, epsilon_max, epsilon_min, epsilon_steps):
        self.image_shape = image_shape
        self.action_space = action_space
        self.learning_rate = learning_rate
        self.rho = rho
        self.optimizer_epsilon = optimizer_epsilon
        self.memory = replay_memory
        self.gamma = gamma
        self.epsilon_max = epsilon_max
        self.epsilon_min = epsilon_min
        self.epsilon_decay = (epsilon_max - epsilon_min)/epsilon_steps
        self.epsilon = epsilon_max
        self.model = self._build_model() # instantiate core model
        self.target_model = self._build_model() # instantiate target model
        self._update_target_model() # set model weights equal for core and target models
    
    def _build_model(self):
        # neural net to approximate Q-value function:
        model = Sequential()
        
        model.add(Conv2D(32, 8, strides = 4, padding = "valid", activation = "relu", input_shape = self.image_shape, 
                 data_format = "channels_last"))
        model.add(Conv2D(64, 4, strides = 2, padding = "valid", activation = "relu"))
        model.add(Conv2D(64, 3, strides = 1, padding = "valid", activation = "relu"))
        model.add(Flatten())
        model.add(Dense(512, activation = "relu"))
        model.add(Dense(action_space))
        
        model.compile(loss = huber_loss, optimizer = RMSprop(lr = self.learning_rate, rho = self.rho, epsilon = self.optimizer_epsilon))
        return model
    
    def _update_target_model(self):
        model_weights = self.model.get_weights()
        self.target_model.set_weights(model_weights)

    def act(self, state):
        state_proc = process_image(state)
        state_scaled = state_proc/128 # convert to [-1,1]
        epsilon = max(self.epsilon_min, self.epsilon)
        if np.random.rand() < epsilon: # if acting randomly, take random action
            return rn.randrange(self.action_space)
        Q_values = self.model.predict(state_scaled)[0] # if not acting randomly, predict Q-values for current state
        return np.argmax(Q_values) # pick the action that will give the highest reward
         
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done)) # list of previous experiences, enabling re-training later
       
    def train(self, batch_size): # method that trains NN with experiences sampled from memory
        state, action, reward, next_state, done = sample_memories(self.memory, batch_size)
        for state, action, reward, next_state, done in zip(state, action, reward, next_state, done): # extract data for each minibatch sample
            target = reward # if done (boolean whether game ended or not, i.e., whether final state or not), then target = reward
            state_scaled = state/128 # convert to [-1,1]
            next_state_scaled = next_state /128 # convert to [-1,1]
            if not done: # if not done, then predict future discounted reward
                target = reward + self.gamma * np.amax(self.target_model.predict(next_state_scaled)[0])
            target_f = self.model.predict(state_scaled) # approximately map current state to future discounted reward
            target_f[0][action] = target
            history = self.model.fit(state_scaled, target_f, epochs = 1, verbose = 0) # single epoch of training with x=state, y=target_f; fit decreases loss btwn target_f and y_hat
        if self.epsilon > self.epsilon_min:
            self.epsilon -= self.epsilon_decay
        return history
            
    def save(self, name):
        self.model.save_weights(name)

    def load(self, name):
        self.model.load_weights(name)

# %%
# Set DQN Agent parameters

## Set RL environment parameters
input_shape = img.shape[1:]
action_space = env.action_space.n


# Set Adam optimizer learning parameters
lr = 0.00025
rho = 0.95
rmsprop_epsilon = 0.01

## Set Q-learning γ discount parameter
gamma = 0.99

## Set ε-greedy learning parameters for actor-agent
epsilon_max = 1
epsilon_min = 0.1
decay_steps = 3*10**4

## Set Rreplay memory parameters
replay_memory_size = 5*10**5
replay_memory = ReplayMemory(replay_memory_size)

## Set output directory for model storage
output_dir = 'double_DQN_model_output/'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Instantiate Deep-Q Learning Agent
agent = DDQNAgent(input_shape, action_space, lr, rho, rmsprop_epsilon, replay_memory, gamma, epsilon_max, epsilon_min, decay_steps)

# %%
# Plot wide model archictecture
plot_model(agent.model, to_file = output_dir + 'ANN_architecture.png', show_shapes = True)
Image(retina = True, filename =  output_dir + 'ANN_architecture.png')

# %%
# Set training defaults
total_frames = 10**5

training_start = 5*10**3
training_frequency = 10
batch_size = 64

copy_steps = 10**3
save_steps = 10**3

run_dict = {    
    'episode':     [],
    'score':       [],
    'epsilon':     [],
    'game length': []
}

loss_history = []

frames = 0
episode = 0

while total_frames > frames:

    done = False   
    state = env.reset()
    loss = np.nan
    
    score = 0
    game_length = 0
    
    while not done:
        
        env.render()

        action = agent.act(state)
        
        next_state, reward, done, _ = env.step(action)
        
        score += reward
        frames += 1
        game_length += 1
        
        agent.remember(process_image(state), action, reward, process_image(next_state), done)
        
        state = next_state
        
        if frames >= training_start:
            if frames % training_frequency == 0:
                model_hist = agent.train(batch_size) 
                loss_history.append(model_hist.history['loss'][0])
        
            if frames % copy_steps == 0:
                agent._update_target_model()
            
            if frames % save_steps == 0:
                agent.save(output_dir + "weights_" + '{:04d}'.format(int(frames/save_steps)) + ".hdf5")
                pd.Series(model_hist).to_csv(output_dir + 'training_loss.csv', index = False, header = False)
                pd.DataFrame.from_dict(run_dict).to_csv(output_dir + 'training_history.csv', index = False)
    
    run_dict['episode'].append(episode)
    run_dict['score'].append(score)
    run_dict['epsilon'].append(agent.epsilon)
    run_dict['game length'].append(game_length)
       
    episode += 1
    
    print("Episode: {:,d} ({:,d} Total Frames): Score: {:.0f} Points, Epsilon: {:.2f}, Game Length: {:,d} Moves".format(
        episode, frames, score, agent.epsilon, game_length))
# Out:
# Episode: 1 (495 Total Frames): Score: 55 Points, Epsilon: 1.00, Game Length: 495 Moves
# Episode: 2 (1,080 Total Frames): Score: 80 Points, Epsilon: 1.00, Game Length: 585 Moves
# Episode: 3 (2,224 Total Frames): Score: 365 Points, Epsilon: 1.00, Game Length: 1,144 Moves
# Episode: 4 (2,981 Total Frames): Score: 180 Points, Epsilon: 1.00, Game Length: 757 Moves
# Episode: 5 (3,389 Total Frames): Score: 140 Points, Epsilon: 1.00, Game Length: 408 Moves
# Episode: 6 (3,810 Total Frames): Score: 55 Points, Epsilon: 1.00, Game Length: 421 Moves
# Episode: 7 (4,328 Total Frames): Score: 60 Points, Epsilon: 1.00, Game Length: 518 Moves
# Episode: 8 (4,949 Total Frames): Score: 65 Points, Epsilon: 1.00, Game Length: 621 Moves
# Episode: 9 (5,459 Total Frames): Score: 55 Points, Epsilon: 1.00, Game Length: 510 Moves
# Episode: 10 (6,091 Total Frames): Score: 135 Points, Epsilon: 1.00, Game Length: 632 Moves
# Episode: 11 (6,885 Total Frames): Score: 115 Points, Epsilon: 0.99, Game Length: 794 Moves
# Episode: 12 (7,499 Total Frames): Score: 150 Points, Epsilon: 0.99, Game Length: 614 Moves
# Episode: 13 (8,160 Total Frames): Score: 135 Points, Epsilon: 0.99, Game Length: 661 Moves
# Episode: 14 (8,991 Total Frames): Score: 165 Points, Epsilon: 0.99, Game Length: 831 Moves
# Episode: 15 (9,477 Total Frames): Score: 100 Points, Epsilon: 0.99, Game Length: 486 Moves
# Episode: 16 (10,258 Total Frames): Score: 120 Points, Epsilon: 0.98, Game Length: 781 Moves
# Episode: 17 (10,794 Total Frames): Score: 70 Points, Epsilon: 0.98, Game Length: 536 Moves
# Episode: 18 (11,174 Total Frames): Score: 80 Points, Epsilon: 0.98, Game Length: 380 Moves
# Episode: 19 (11,823 Total Frames): Score: 210 Points, Epsilon: 0.98, Game Length: 649 Moves
# Episode: 20 (12,340 Total Frames): Score: 120 Points, Epsilon: 0.98, Game Length: 517 Moves
# Episode: 21 (13,055 Total Frames): Score: 210 Points, Epsilon: 0.98, Game Length: 715 Moves
# Episode: 22 (14,294 Total Frames): Score: 365 Points, Epsilon: 0.97, Game Length: 1,239 Moves
# Episode: 23 (14,992 Total Frames): Score: 110 Points, Epsilon: 0.97, Game Length: 698 Moves
# Episode: 24 (15,615 Total Frames): Score: 80 Points, Epsilon: 0.97, Game Length: 623 Moves
# Episode: 25 (16,275 Total Frames): Score: 65 Points, Epsilon: 0.97, Game Length: 660 Moves
# Episode: 26 (16,945 Total Frames): Score: 110 Points, Epsilon: 0.96, Game Length: 670 Moves
# Episode: 27 (17,346 Total Frames): Score: 45 Points, Epsilon: 0.96, Game Length: 401 Moves
# Episode: 28 (17,898 Total Frames): Score: 30 Points, Epsilon: 0.96, Game Length: 552 Moves
# Episode: 29 (18,829 Total Frames): Score: 215 Points, Epsilon: 0.96, Game Length: 931 Moves
# Episode: 30 (19,558 Total Frames): Score: 135 Points, Epsilon: 0.96, Game Length: 729 Moves
# Episode: 31 (20,485 Total Frames): Score: 230 Points, Epsilon: 0.95, Game Length: 927 Moves
# Episode: 32 (21,373 Total Frames): Score: 260 Points, Epsilon: 0.95, Game Length: 888 Moves
# Episode: 33 (21,970 Total Frames): Score: 115 Points, Epsilon: 0.95, Game Length: 597 Moves
# Episode: 34 (22,796 Total Frames): Score: 210 Points, Epsilon: 0.95, Game Length: 826 Moves
# Episode: 35 (23,578 Total Frames): Score: 210 Points, Epsilon: 0.94, Game Length: 782 Moves
# Episode: 36 (24,174 Total Frames): Score: 50 Points, Epsilon: 0.94, Game Length: 596 Moves
# Episode: 37 (25,173 Total Frames): Score: 180 Points, Epsilon: 0.94, Game Length: 999 Moves
# Episode: 38 (25,645 Total Frames): Score: 110 Points, Epsilon: 0.94, Game Length: 472 Moves
# Episode: 39 (26,185 Total Frames): Score: 55 Points, Epsilon: 0.94, Game Length: 540 Moves
# Episode: 40 (26,594 Total Frames): Score: 80 Points, Epsilon: 0.94, Game Length: 409 Moves
# Episode: 41 (27,204 Total Frames): Score: 35 Points, Epsilon: 0.93, Game Length: 610 Moves
# Episode: 42 (27,577 Total Frames): Score: 100 Points, Epsilon: 0.93, Game Length: 373 Moves
# Episode: 43 (28,203 Total Frames): Score: 105 Points, Epsilon: 0.93, Game Length: 626 Moves
# Episode: 44 (28,848 Total Frames): Score: 120 Points, Epsilon: 0.93, Game Length: 645 Moves
# Episode: 45 (29,376 Total Frames): Score: 70 Points, Epsilon: 0.93, Game Length: 528 Moves
# Episode: 46 (29,991 Total Frames): Score: 150 Points, Epsilon: 0.93, Game Length: 615 Moves
# Episode: 47 (30,639 Total Frames): Score: 105 Points, Epsilon: 0.92, Game Length: 648 Moves
# Episode: 48 (31,982 Total Frames): Score: 450 Points, Epsilon: 0.92, Game Length: 1,343 Moves
# Episode: 49 (32,605 Total Frames): Score: 180 Points, Epsilon: 0.92, Game Length: 623 Moves
# Episode: 50 (33,398 Total Frames): Score: 210 Points, Epsilon: 0.91, Game Length: 793 Moves
# Episode: 51 (34,035 Total Frames): Score: 145 Points, Epsilon: 0.91, Game Length: 637 Moves
# Episode: 52 (34,885 Total Frames): Score: 210 Points, Epsilon: 0.91, Game Length: 850 Moves
# Episode: 53 (35,635 Total Frames): Score: 180 Points, Epsilon: 0.91, Game Length: 750 Moves
# Episode: 54 (36,788 Total Frames): Score: 210 Points, Epsilon: 0.90, Game Length: 1,153 Moves
# Episode: 55 (37,345 Total Frames): Score: 105 Points, Epsilon: 0.90, Game Length: 557 Moves
# Episode: 56 (38,096 Total Frames): Score: 155 Points, Epsilon: 0.90, Game Length: 751 Moves
# Episode: 57 (38,501 Total Frames): Score: 40 Points, Epsilon: 0.90, Game Length: 405 Moves
# Episode: 58 (39,286 Total Frames): Score: 210 Points, Epsilon: 0.90, Game Length: 785 Moves
# Episode: 59 (39,926 Total Frames): Score: 155 Points, Epsilon: 0.90, Game Length: 640 Moves
# Episode: 60 (40,545 Total Frames): Score: 65 Points, Epsilon: 0.89, Game Length: 619 Moves
# Episode: 61 (41,443 Total Frames): Score: 195 Points, Epsilon: 0.89, Game Length: 898 Moves
# Episode: 62 (42,296 Total Frames): Score: 230 Points, Epsilon: 0.89, Game Length: 853 Moves
# Episode: 63 (43,145 Total Frames): Score: 255 Points, Epsilon: 0.89, Game Length: 849 Moves
# Episode: 64 (44,333 Total Frames): Score: 260 Points, Epsilon: 0.88, Game Length: 1,188 Moves
# Episode: 65 (45,100 Total Frames): Score: 210 Points, Epsilon: 0.88, Game Length: 767 Moves
# Episode: 66 (45,849 Total Frames): Score: 150 Points, Epsilon: 0.88, Game Length: 749 Moves
# Episode: 67 (46,301 Total Frames): Score: 90 Points, Epsilon: 0.88, Game Length: 452 Moves
# Episode: 68 (46,806 Total Frames): Score: 55 Points, Epsilon: 0.87, Game Length: 505 Moves
# Episode: 69 (47,508 Total Frames): Score: 135 Points, Epsilon: 0.87, Game Length: 702 Moves
# Episode: 70 (48,111 Total Frames): Score: 160 Points, Epsilon: 0.87, Game Length: 603 Moves
# Episode: 71 (48,759 Total Frames): Score: 135 Points, Epsilon: 0.87, Game Length: 648 Moves
# Episode: 72 (49,401 Total Frames): Score: 105 Points, Epsilon: 0.87, Game Length: 642 Moves
# Episode: 73 (50,267 Total Frames): Score: 205 Points, Epsilon: 0.86, Game Length: 866 Moves
# Episode: 74 (50,670 Total Frames): Score: 65 Points, Epsilon: 0.86, Game Length: 403 Moves
# Episode: 75 (51,228 Total Frames): Score: 105 Points, Epsilon: 0.86, Game Length: 558 Moves
# Episode: 76 (51,831 Total Frames): Score: 75 Points, Epsilon: 0.86, Game Length: 603 Moves
# Episode: 77 (52,446 Total Frames): Score: 150 Points, Epsilon: 0.86, Game Length: 615 Moves
# Episode: 78 (52,954 Total Frames): Score: 80 Points, Epsilon: 0.86, Game Length: 508 Moves
# Episode: 79 (53,732 Total Frames): Score: 155 Points, Epsilon: 0.85, Game Length: 778 Moves
# Episode: 80 (54,378 Total Frames): Score: 180 Points, Epsilon: 0.85, Game Length: 646 Moves
# Episode: 81 (54,878 Total Frames): Score: 90 Points, Epsilon: 0.85, Game Length: 500 Moves
# Episode: 82 (55,512 Total Frames): Score: 160 Points, Epsilon: 0.85, Game Length: 634 Moves
# Episode: 83 (55,870 Total Frames): Score: 75 Points, Epsilon: 0.85, Game Length: 358 Moves
# Episode: 84 (56,478 Total Frames): Score: 120 Points, Epsilon: 0.85, Game Length: 608 Moves
# Episode: 85 (57,297 Total Frames): Score: 245 Points, Epsilon: 0.84, Game Length: 819 Moves
# Episode: 86 (57,946 Total Frames): Score: 135 Points, Epsilon: 0.84, Game Length: 649 Moves
# Episode: 87 (58,470 Total Frames): Score: 95 Points, Epsilon: 0.84, Game Length: 524 Moves
# Episode: 88 (59,070 Total Frames): Score: 110 Points, Epsilon: 0.84, Game Length: 600 Moves
# Episode: 89 (59,677 Total Frames): Score: 105 Points, Epsilon: 0.84, Game Length: 607 Moves
# Episode: 90 (60,049 Total Frames): Score: 95 Points, Epsilon: 0.83, Game Length: 372 Moves
# Episode: 91 (60,676 Total Frames): Score: 140 Points, Epsilon: 0.83, Game Length: 627 Moves
# Episode: 92 (61,231 Total Frames): Score: 105 Points, Epsilon: 0.83, Game Length: 555 Moves
# Episode: 93 (61,605 Total Frames): Score: 55 Points, Epsilon: 0.83, Game Length: 374 Moves
# Episode: 94 (62,157 Total Frames): Score: 60 Points, Epsilon: 0.83, Game Length: 552 Moves
# Episode: 95 (63,163 Total Frames): Score: 410 Points, Epsilon: 0.83, Game Length: 1,006 Moves
# Episode: 96 (63,796 Total Frames): Score: 120 Points, Epsilon: 0.82, Game Length: 633 Moves
# Episode: 97 (64,247 Total Frames): Score: 110 Points, Epsilon: 0.82, Game Length: 451 Moves
# Episode: 98 (64,995 Total Frames): Score: 135 Points, Epsilon: 0.82, Game Length: 748 Moves
# Episode: 99 (65,632 Total Frames): Score: 65 Points, Epsilon: 0.82, Game Length: 637 Moves
# Episode: 100 (66,193 Total Frames): Score: 55 Points, Epsilon: 0.82, Game Length: 561 Moves
# Episode: 101 (66,590 Total Frames): Score: 45 Points, Epsilon: 0.82, Game Length: 397 Moves
# Episode: 102 (67,642 Total Frames): Score: 515 Points, Epsilon: 0.81, Game Length: 1,052 Moves
# Episode: 103 (68,049 Total Frames): Score: 20 Points, Epsilon: 0.81, Game Length: 407 Moves
# Episode: 104 (68,740 Total Frames): Score: 110 Points, Epsilon: 0.81, Game Length: 691 Moves
# Episode: 105 (69,327 Total Frames): Score: 105 Points, Epsilon: 0.81, Game Length: 587 Moves
# Episode: 106 (69,821 Total Frames): Score: 35 Points, Epsilon: 0.81, Game Length: 494 Moves
# Episode: 107 (70,199 Total Frames): Score: 60 Points, Epsilon: 0.80, Game Length: 378 Moves
# Episode: 108 (70,981 Total Frames): Score: 160 Points, Epsilon: 0.80, Game Length: 782 Moves
# Episode: 109 (71,359 Total Frames): Score: 35 Points, Epsilon: 0.80, Game Length: 378 Moves
# Episode: 110 (71,742 Total Frames): Score: 65 Points, Epsilon: 0.80, Game Length: 383 Moves
# Episode: 111 (72,231 Total Frames): Score: 30 Points, Epsilon: 0.80, Game Length: 489 Moves
# Episode: 112 (72,851 Total Frames): Score: 85 Points, Epsilon: 0.80, Game Length: 620 Moves
# Episode: 113 (73,238 Total Frames): Score: 35 Points, Epsilon: 0.80, Game Length: 387 Moves
# Episode: 114 (74,242 Total Frames): Score: 180 Points, Epsilon: 0.79, Game Length: 1,004 Moves
# Episode: 115 (75,324 Total Frames): Score: 515 Points, Epsilon: 0.79, Game Length: 1,082 Moves
# Episode: 116 (76,054 Total Frames): Score: 105 Points, Epsilon: 0.79, Game Length: 730 Moves
# Episode: 117 (76,917 Total Frames): Score: 185 Points, Epsilon: 0.78, Game Length: 863 Moves
# Episode: 118 (77,568 Total Frames): Score: 135 Points, Epsilon: 0.78, Game Length: 651 Moves
# Episode: 119 (78,079 Total Frames): Score: 35 Points, Epsilon: 0.78, Game Length: 511 Moves
# Episode: 120 (78,546 Total Frames): Score: 105 Points, Epsilon: 0.78, Game Length: 467 Moves
# Episode: 121 (79,231 Total Frames): Score: 185 Points, Epsilon: 0.78, Game Length: 685 Moves
# Episode: 122 (79,696 Total Frames): Score: 75 Points, Epsilon: 0.78, Game Length: 465 Moves
# Episode: 123 (80,366 Total Frames): Score: 115 Points, Epsilon: 0.77, Game Length: 670 Moves
# Episode: 124 (81,315 Total Frames): Score: 260 Points, Epsilon: 0.77, Game Length: 949 Moves
# Episode: 125 (81,952 Total Frames): Score: 115 Points, Epsilon: 0.77, Game Length: 637 Moves
# Episode: 126 (82,656 Total Frames): Score: 210 Points, Epsilon: 0.77, Game Length: 704 Moves
# Episode: 127 (83,361 Total Frames): Score: 170 Points, Epsilon: 0.76, Game Length: 705 Moves
# Episode: 128 (84,271 Total Frames): Score: 365 Points, Epsilon: 0.76, Game Length: 910 Moves
# Episode: 129 (84,851 Total Frames): Score: 105 Points, Epsilon: 0.76, Game Length: 580 Moves
# Episode: 130 (85,539 Total Frames): Score: 290 Points, Epsilon: 0.76, Game Length: 688 Moves
# Episode: 131 (85,921 Total Frames): Score: 100 Points, Epsilon: 0.76, Game Length: 382 Moves
# Episode: 132 (86,780 Total Frames): Score: 395 Points, Epsilon: 0.75, Game Length: 859 Moves
# Episode: 133 (87,290 Total Frames): Score: 125 Points, Epsilon: 0.75, Game Length: 510 Moves
# Episode: 134 (88,093 Total Frames): Score: 235 Points, Epsilon: 0.75, Game Length: 803 Moves
# Episode: 135 (89,223 Total Frames): Score: 215 Points, Epsilon: 0.75, Game Length: 1,130 Moves
# Episode: 136 (89,730 Total Frames): Score: 105 Points, Epsilon: 0.75, Game Length: 507 Moves
# Episode: 137 (90,427 Total Frames): Score: 210 Points, Epsilon: 0.74, Game Length: 697 Moves
# Episode: 138 (91,291 Total Frames): Score: 150 Points, Epsilon: 0.74, Game Length: 864 Moves
# Episode: 139 (92,237 Total Frames): Score: 180 Points, Epsilon: 0.74, Game Length: 946 Moves
# Episode: 140 (93,037 Total Frames): Score: 115 Points, Epsilon: 0.74, Game Length: 800 Moves
# Episode: 141 (93,423 Total Frames): Score: 30 Points, Epsilon: 0.73, Game Length: 386 Moves
# Episode: 142 (94,324 Total Frames): Score: 240 Points, Epsilon: 0.73, Game Length: 901 Moves
# Episode: 143 (95,107 Total Frames): Score: 95 Points, Epsilon: 0.73, Game Length: 783 Moves
# Episode: 144 (95,604 Total Frames): Score: 65 Points, Epsilon: 0.73, Game Length: 497 Moves
# Episode: 145 (96,231 Total Frames): Score: 145 Points, Epsilon: 0.73, Game Length: 627 Moves
# Episode: 146 (96,911 Total Frames): Score: 160 Points, Epsilon: 0.72, Game Length: 680 Moves
# Episode: 147 (97,491 Total Frames): Score: 45 Points, Epsilon: 0.72, Game Length: 580 Moves
# Episode: 148 (98,288 Total Frames): Score: 210 Points, Epsilon: 0.72, Game Length: 797 Moves
# Episode: 149 (99,533 Total Frames): Score: 515 Points, Epsilon: 0.72, Game Length: 1,245 Moves
# Episode: 150 (100,163 Total Frames): Score: 135 Points, Epsilon: 0.71, Game Length: 630 Moves

# %%
# Set visualization defaults
plt.style.use('seaborn-darkgrid')

loss = pd.Series(loss_history)

loss_av_100 = loss.rolling(100).mean()
loss_av_1K = loss.rolling(1000).mean()

# Plot Learning Curve
fig = plt.figure()

ax = fig.add_subplot(111)

plt.plot(loss, label = 'Huber Loss')
plt.plot(loss_av_100, label = 'Rolling Average (100 Training Steps)')
plt.plot(loss_av_1K, label = 'Rolling Average (1,000 Training Steps)')

plt.title('Deep-Q Network Learning Curve', fontweight = 'bold')


ax.set_xticklabels(['{:}'.format(training_start + x * training_frequency) for x in ax.get_xticks()])
plt.xlabel('Frames')
plt.ylabel('Huber Loss')

plt.legend()

# %%
clipped_loss = pd.Series(np.minimum(np.array(loss), np.ones(len(loss))))

clipped_loss_av_100 = clipped_loss.rolling(100).mean()
clipped_loss_av_1K = clipped_loss.rolling(1000).mean()

plt.plot(clipped_loss, label = 'Clipped Huber Loss ([0,1])')
plt.plot(clipped_loss_av_100, label = 'Rolling Average (100 Training Steps)')
plt.plot(clipped_loss_av_1K, label = 'Rolling Average (1,000 Training Steps)')

plt.title('Deep-Q Network Learning Curve', fontweight = 'bold')


ax.set_xticklabels(['{:}'.format(training_start + x * training_frequency) for x in ax.get_xticks()])
plt.xlabel('Frames')
plt.ylabel('Huber Loss')

plt.legend()

# %%
score_av_10 = pd.Series(run_dict['score']).rolling(10).mean()
score_av_100 = pd.Series(run_dict['score']).rolling(100).mean()

# Plot 
fig = plt.figure()

ax = fig.add_subplot(111)

plt.plot(run_dict['episode'], run_dict['score'], label = 'Game Score')
plt.plot(run_dict['episode'], score_av_10, label = 'Rolling Average (10 Episodes)')
plt.plot(run_dict['episode'], score_av_100, label = 'Rolling Average (100 Episodes)')

plt.title('Deep-Q Network Scoring Performance', fontweight = 'bold')

plt.xlabel('Episode')
plt.ylabel('Game Score')

plt.legend()

# %%
gl_av_10 = pd.Series(run_dict['game length']).rolling(10).mean()
gl_100 = pd.Series(run_dict['game length']).rolling(100).mean()

# Plot 
fig = plt.figure()

ax = fig.add_subplot(111)

plt.plot(run_dict['episode'], run_dict['game length'], label = 'Game Length')
plt.plot(run_dict['episode'], gl_av_10, label = 'Rolling Average (10 Episodes)')
plt.plot(run_dict['episode'], gl_100, label = 'Rolling Average (100 Episodes)')

plt.title('Deep-Q Network Scoring Performance', fontweight = 'bold')

plt.xlabel('Episode')
plt.ylabel('Game Length')

plt.legend()
