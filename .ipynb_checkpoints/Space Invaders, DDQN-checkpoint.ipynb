# %%
#import dependencies
import pandas as pd
import numpy as np
import random as rn
from datetime import datetime
import gym
from keras import backend as K
from keras.models import Sequential
from keras.optimizers import RMSprop
from keras.layers import Conv2D, Dense, Flatten, BatchNormalization
import tensorflow as tf
from tensorflow.losses import huber_loss
import os
from keras.utils import plot_model
from IPython.display import Image
from matplotlib import pyplot as plt
from  matplotlib import animation as animation
import seaborn as sns


# Add graphviz to PATH environmental variable (for NN model architecture visualizations)
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

# Set randomization defaults for solution reproducability
np.random.seed(21)
rn.seed(21)
tf.set_random_seed(21)

# Set conditions for keras result reproducability
session_conf = tf.ConfigProto(intra_op_parallelism_threads = 1, inter_op_parallelism_threads = 1)
sess = tf.Session(graph = tf.get_default_graph(), config = session_conf)
K.set_session(sess)

# Set visualization defaults
sns.set_context('notebook')

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
env = gym.make('SpaceInvaders-v0') # Instantiate Space Invaders gym environemtn
obs = env.reset() # Initialize environment

print('Space Invaders Display Dimensions: {:} x {:} x {:}'.format(obs.shape[0], obs.shape[1], obs.shape[2]))
print('Action Space Size: {:} Options'.format(env.action_space.n))
# Out:
# Space Invaders Display Dimensions: 210 x 160 x 3
# Action Space Size: 6 Options

# %%
def process_image(obs):
    img = obs[12:195:2, ::2] # Trim image to playable display domain, downsample
    img = img.mean(axis = 2) # Convert image to greyscale
    img = img.astype(np.uint8)  # Cast pixel values as integers
    img = img.reshape((1,) + img.shape + (1,)) # Reshape image to 4D array of dimensions 1 x H x L x 1 for Keras compatibility
    return img # return processed image array

# %%
# Apply image processing helper function to initial environment observation
img = process_image(obs) 

# Plot image; print dimensions for 4D image array
fig = plt.figure()
ax = fig.add_subplot(111)

ax.axis("off")
plt.imshow(img.reshape(img.shape[1], img.shape[2]))

print('Processed Image Array Dimension: {:} x {:} x {:} x {:}'.format(img.shape[0], img.shape[1], img.shape[2], img.shape[3]))
# Out:
# Processed Image Array Dimension: 1 x 92 x 80 x 1

# %%
class ReplayMemory:
    def __init__(self, maxlen):
        self.maxlen = int(maxlen)
        self.buf = np.empty(shape = self.maxlen, dtype = np.object)
        self.index = 0
        self.length = 0
        
    def append(self, data): # Define method for storing samples in replay memory buffer
        self.buf[self.index] = data
        self.length = min(self.length + 1, self.maxlen)
        self.index = (self.index + 1) % self.maxlen # If `maxlen` is exceeded, replace prior memory samples with new observations
    
    def sample(self, batch_size, with_replacement = True): # Define method for randomly sampling replay memory; default to sampling with replacement (faster than alternative)
        if with_replacement:
            indices = np.random.randint(self.length, size = batch_size)
        else:
            indices = np.random.permutation(self.length)[:batch_size]
        return self.buf[indices]

# Define helper function for randomly sampling from memory buffer of class `ReplayMemory`
def sample_memories(memory_store, batch_size):
    cols = [[], [], [], [], []]
    for memory in memory_store.sample(batch_size):
        for col, value in zip(cols, memory):
            col.append(value)
    cols = [np.array(col) for col in cols]
    return cols[0], cols[1], cols[2].reshape(-1, 1), cols[3], cols[4].reshape(-1, 1)

# %%
# Declare Double Deep-Q Learning Network Agent class
class DDQNAgent:
    def __init__(self, image_shape, action_space, learning_rate, rho, optimizer_epsilon, replay_memory, gamma, epsilon_max, epsilon_min, epsilon_steps):
        self.image_shape = image_shape
        self.action_space = action_space
        self.learning_rate = learning_rate
        self.rho = rho
        self.optimizer_epsilon = optimizer_epsilon
        self.memory = replay_memory
        self.gamma = gamma
        self.epsilon_max = epsilon_max
        self.epsilon_min = epsilon_min
        self.epsilon_decay = (epsilon_max - epsilon_min)/epsilon_steps # set step size for decay from `epsilon_max` to `epsilon_min` over `epsilon_step` steps
        self.ε = epsilon_max # set initial ε-greedy learning `ε` parameter value equal to `epsilon_max`
        self.model, self.target_model = self._build_model() # instantiate core model, target model (same initial weights)
    
    def _build_model(self): # Define ANN architecture for Deep-Q Network Learning:
        model = Sequential()
        
        model.add(Conv2D(32, 8, strides = 4, padding = "valid", activation = "relu", input_shape = self.image_shape, data_format = "channels_last"))
        model.add(Conv2D(64, 4, strides = 2, padding = "valid", activation = "relu"))
        model.add(Conv2D(64, 3, strides = 1, padding = "valid", activation = "relu"))
        model.add(Flatten())
        model.add(Dense(512, activation = "relu"))
        model.add(Dense(self.action_space))
        
        model.compile(loss = huber_loss, optimizer = RMSprop(lr = self.learning_rate, rho = self.rho, epsilon = self.optimizer_epsilon))
        return model, model

    def act(self, state): # Define ε-greedy learning action method
        
        ## Apply image processing helper function to current environment state; convert image pixel values to [0,1]
        state_proc = process_image(state)
        state_scaled = state_proc/255
        
        ## Perform action based on ε value: 
        ε = max(self.epsilon_min, self.ε)
        
        ### If Agent acting randomly, select random action from available action-space
        if np.random.rand() < ε:
            return rn.randrange(self.action_space)
        
        ### If Agent not acting randomly, choose action based on policy of selecting action yielding highest Q-value
        Q_value = self.model.predict(state_scaled)[0] 
        return np.argmax(Q_value)
         
    def remember(self, state, action, reward, next_state, done): # Define method for appending agent experiences to memory buffer
        self.memory.append((state, action, reward, next_state, done)) 
       
    def train(self, batch_size): # Define method for Agent to traing DNN with experiences sampled from memory buffer
        ## Extract minibatch samples from memory buffer
        state, action, reward, next_state, done = sample_memories(self.memory, batch_size)
        
        ## Convert current, next state observation pixel values to [0,1]
        state_scaled = state/255
        next_state_scaled = next_state/255
        
        ## Update best Q value for each observation within minibatch
        for state_scaled, action, reward, next_state_scaled, done in zip(state_scaled, action, reward, next_state_scaled, done):
            
            ### Predict Q-values for current state
            Q_values = self.model.predict(state_scaled) 
            
            ### Update Q-value for selected action
            target = reward ### If training episode is complete, set Q-value for selected action equal to present reward
            if not done: ### If episode is ongoing, set Q-value for selected action discounted future Q-value predicted using target model
                target = reward + self.gamma * np.amax(self.target_model.predict(next_state_scaled)[0]) 
    
            Q_values[0][action] = target
            
        ## Fit online model on minibatch to optimize quality of Q-value prediction for selected action; update ε-greedy learning parameter value
        history = self.model.fit(state_scaled, Q_values, batch_size = batch_size, epochs = 1, verbose = 0)
        
        if self.ε > self.epsilon_min:
            self.ε -= self.epsilon_decay
            
        return history
    
    def update_target_model(self): # Define method to copy online DQN model feature weights to target model
        model_weights = self.model.get_weights()
        self.target_model.set_weights(model_weights)
        
    def save(self, name): # Define method for saving model weights
        self.model.save_weights(name)

    def load(self, name): # Define method for loading saved model weights
        self.model.load_weights(name)

# %%
# Set DQN Agent parameters
## Set RL environment parameters
INPUT_SHAPE = img.shape[1:]
ACTION_SPACE = env.action_space.n

# Set RMSProp optimizer learning parameters
LEARNING_RATE = 0.00025
RHO = 0.95
OPTIMIZER_EPSILON = 0.01

## Set Q-learning γ discount-rate parameter
GAMMA = 0.99

## Set replay memory size parameter; instantiate memory buffer
REPLAY_MEMORY_SIZE = 6 * 10**4
REPLAY_MEMORY = ReplayMemory(REPLAY_MEMORY_SIZE)

## Set ε-greedy learning parameters for actor-agent
EPSILON_MAX = 1
EPSILON_MIN = 0.1
DECAY_STEPS = 2 * 10**4

## Set output directory for model storage
OUTPUT_DIR = 'ddqn_model_output/'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# Instantiate Deep-Q Learning Agent
agent = DDQNAgent(INPUT_SHAPE, ACTION_SPACE, LEARNING_RATE, RHO, OPTIMIZER_EPSILON, REPLAY_MEMORY, GAMMA, EPSILON_MAX, EPSILON_MIN, DECAY_STEPS)

# %%
# Plot ANN archictecture
plot_model(agent.model, to_file = OUTPUT_DIR + 'ANN_architecture.png', show_shapes = True)
Image(retina = True, filename =  OUTPUT_DIR + 'ANN_architecture.png')

# %%
# Set training defaults
TOTAL_FRAMES = 2 * 10**5 # Total frames for DDQN training
SPAWN_SKIP = 40 # Frames at start of episode skipped before simulation start (no user control) 
RESPAWN_SKIP = 20 # Frames skipped after loss of life
TRAINING_START = 10**4 # Frames simulated before DDQN training begins
TRAINING_FREQUENCY = 3 # Game frames per model training step
BATCH_SIZE = 64 # Minibatch DQN SGD batch size
COPY_STEPS = 2 * 10**3 # Frames per online model -> target model copy step
SAVE_STEPS = 2 * 10**3 # Frames per trained model save

# Define dictionary for storing training performance
run_dict = {    
    'game':    [],
    'score':   [],
    'epsilon': [],
    'length':  []
}

# Define list for storing DQN training loss history
loss_history = []

# Initialize training defaults
frames = 0
game = 0
start_time = datetime.now()
game_lives = 3

# Begin training Loop
while frames < TOTAL_FRAMES:
    
    # Reset training defauls for episode
    env.reset()
    done = False
    score = 0
    length = 0
    respawn_frames = 0
    
    # Loop over frames of episode duration
    while not done:
        
        env.render() # Render game
        
        ## Skip initial frames of episode (no agent control)
        while length < SPAWN_SKIP:
            state, _, _, lives = env.step(0)
            
            lives = lives['ale.lives']
            frames += 1
            length += 1
        
        ## While agent is "alive", play game
        if game_lives == lives:
            
            ### Perform ε-greedly learning, update running score
            action = agent.act(state)
            next_state, reward, done, lives = env.step(action)
            
            lives = lives['ale.lives']
            score += reward

            ### Commit action results to agent memory buffer, update `state` variable
            agent.remember(process_image(state), action, reward, process_image(next_state), done)
            state = next_state
        
        ## After agent "dies", skip forward until sufficient "respawn frames" have passed to resume play
        else:
            state, reward, done, _ = env.step(0)
            
            respawn_frames += 1
            score += reward
            
            ### After sufficient wait time, resume gameplay 
            if respawn_frames == RESPAWN_SKIP:
                
                game_lives = lives
                respawn_frames = 0
        
        ## Update frame, game length counters
        frames += 1
        length += 1
        
        ## Repeat with fully stochastic agent actions until training start frame-threshold (`training_start`) is met
        if frames < TRAINING_START:
            continue
        
        ## Retrain model at intervals of predetermined frame frequency (`training_frequency`), store training loss
        if frames % TRAINING_FREQUENCY == 0:
            model_hist = agent.train(BATCH_SIZE) 
            loss_history.append(model_hist.history['loss'][0])
        
        ## Copy online model to target model at intervals of `copy_steps` frames
        if frames % COPY_STEPS == 0:
            agent.update_target_model()
        
        ## Save model artifact, loss history, training history at intervals of `save_steps` frames
        if frames % SAVE_STEPS == 0:
            agent.save(OUTPUT_DIR + "weights_{:03d}K_frames.hdf5".format(int(frames/SAVE_STEPS)))
            pd.Series(loss_history).to_csv(OUTPUT_DIR + 'training_loss.csv', index = False, header = False)
            pd.DataFrame.from_dict(run_dict).to_csv(OUTPUT_DIR + 'training_history.csv', index = False)
    
    # With game episode concluded, update game counter; store episode metrics; print episode result
    game += 1
    
    run_dict['game'].append(game)
    run_dict['score'].append(score)
    run_dict['epsilon'].append(agent.ε)
    run_dict['length'].append(length)

    print("Game: {:,d} ({:,d} Total Frames): Score: {:.0f} Points, Final Epsilon: {:.2f}, Game Length: {:,d} Moves".format(
        game, frames, score, agent.ε, length))   

# Record, print training duration
env.close()
end_time = datetime.now()

print('')
print("Training Time: {:}".format(end_time - start_time))
# Out:
# Game: 1 (744 Total Frames): Score: 155 Points, Final Epsilon: 1.00, Game Length: 744 Moves
# Game: 2 (1,534 Total Frames): Score: 185 Points, Final Epsilon: 1.00, Game Length: 790 Moves
# Game: 3 (2,337 Total Frames): Score: 185 Points, Final Epsilon: 1.00, Game Length: 803 Moves
# Game: 4 (3,091 Total Frames): Score: 165 Points, Final Epsilon: 1.00, Game Length: 754 Moves
# Game: 5 (3,993 Total Frames): Score: 120 Points, Final Epsilon: 1.00, Game Length: 902 Moves
# Game: 6 (5,214 Total Frames): Score: 255 Points, Final Epsilon: 1.00, Game Length: 1,221 Moves
# Game: 7 (6,421 Total Frames): Score: 360 Points, Final Epsilon: 1.00, Game Length: 1,207 Moves
# Game: 8 (7,134 Total Frames): Score: 155 Points, Final Epsilon: 1.00, Game Length: 713 Moves
# Game: 9 (7,786 Total Frames): Score: 110 Points, Final Epsilon: 1.00, Game Length: 652 Moves
# Game: 10 (8,269 Total Frames): Score: 35 Points, Final Epsilon: 1.00, Game Length: 483 Moves
# Game: 11 (8,770 Total Frames): Score: 30 Points, Final Epsilon: 1.00, Game Length: 501 Moves
# Game: 12 (9,256 Total Frames): Score: 50 Points, Final Epsilon: 1.00, Game Length: 486 Moves
# Game: 13 (9,845 Total Frames): Score: 35 Points, Final Epsilon: 1.00, Game Length: 589 Moves
# Game: 14 (10,418 Total Frames): Score: 20 Points, Final Epsilon: 0.99, Game Length: 573 Moves
# Game: 15 (10,790 Total Frames): Score: 80 Points, Final Epsilon: 0.99, Game Length: 372 Moves
# Game: 16 (11,551 Total Frames): Score: 135 Points, Final Epsilon: 0.98, Game Length: 761 Moves
# Game: 17 (12,507 Total Frames): Score: 215 Points, Final Epsilon: 0.96, Game Length: 956 Moves
# Game: 18 (13,271 Total Frames): Score: 110 Points, Final Epsilon: 0.95, Game Length: 764 Moves
# Game: 19 (13,625 Total Frames): Score: 65 Points, Final Epsilon: 0.95, Game Length: 354 Moves
# Game: 20 (14,279 Total Frames): Score: 100 Points, Final Epsilon: 0.94, Game Length: 654 Moves
# Game: 21 (15,149 Total Frames): Score: 210 Points, Final Epsilon: 0.93, Game Length: 870 Moves
# Game: 22 (16,122 Total Frames): Score: 440 Points, Final Epsilon: 0.91, Game Length: 973 Moves
# Game: 23 (17,568 Total Frames): Score: 400 Points, Final Epsilon: 0.89, Game Length: 1,446 Moves
# Game: 24 (18,543 Total Frames): Score: 330 Points, Final Epsilon: 0.88, Game Length: 975 Moves
# Game: 25 (19,251 Total Frames): Score: 130 Points, Final Epsilon: 0.87, Game Length: 708 Moves
# Game: 26 (20,088 Total Frames): Score: 210 Points, Final Epsilon: 0.86, Game Length: 837 Moves
# Game: 27 (20,792 Total Frames): Score: 70 Points, Final Epsilon: 0.85, Game Length: 704 Moves
# Game: 28 (21,420 Total Frames): Score: 100 Points, Final Epsilon: 0.84, Game Length: 628 Moves
# Game: 29 (21,876 Total Frames): Score: 90 Points, Final Epsilon: 0.83, Game Length: 456 Moves
# Game: 30 (22,908 Total Frames): Score: 305 Points, Final Epsilon: 0.82, Game Length: 1,032 Moves
# Game: 31 (23,437 Total Frames): Score: 75 Points, Final Epsilon: 0.81, Game Length: 529 Moves
# Game: 32 (23,850 Total Frames): Score: 50 Points, Final Epsilon: 0.80, Game Length: 413 Moves
# Game: 33 (24,769 Total Frames): Score: 225 Points, Final Epsilon: 0.79, Game Length: 919 Moves
# Game: 34 (25,369 Total Frames): Score: 90 Points, Final Epsilon: 0.78, Game Length: 600 Moves
# Game: 35 (26,537 Total Frames): Score: 335 Points, Final Epsilon: 0.76, Game Length: 1,168 Moves
# Game: 36 (27,198 Total Frames): Score: 125 Points, Final Epsilon: 0.76, Game Length: 661 Moves
# Game: 37 (28,018 Total Frames): Score: 185 Points, Final Epsilon: 0.74, Game Length: 820 Moves
# Game: 38 (28,448 Total Frames): Score: 105 Points, Final Epsilon: 0.74, Game Length: 430 Moves
# Game: 39 (28,841 Total Frames): Score: 75 Points, Final Epsilon: 0.73, Game Length: 393 Moves
# Game: 40 (29,523 Total Frames): Score: 110 Points, Final Epsilon: 0.72, Game Length: 682 Moves
# Game: 41 (29,995 Total Frames): Score: 35 Points, Final Epsilon: 0.72, Game Length: 472 Moves
# Game: 42 (31,433 Total Frames): Score: 495 Points, Final Epsilon: 0.70, Game Length: 1,438 Moves
# Game: 43 (32,181 Total Frames): Score: 135 Points, Final Epsilon: 0.68, Game Length: 748 Moves
# Game: 44 (32,958 Total Frames): Score: 240 Points, Final Epsilon: 0.67, Game Length: 777 Moves
# Game: 45 (33,659 Total Frames): Score: 130 Points, Final Epsilon: 0.66, Game Length: 701 Moves
# Game: 46 (34,133 Total Frames): Score: 55 Points, Final Epsilon: 0.66, Game Length: 474 Moves
# Game: 47 (35,239 Total Frames): Score: 315 Points, Final Epsilon: 0.64, Game Length: 1,106 Moves
# Game: 48 (36,360 Total Frames): Score: 485 Points, Final Epsilon: 0.63, Game Length: 1,121 Moves
# Game: 49 (36,998 Total Frames): Score: 60 Points, Final Epsilon: 0.62, Game Length: 638 Moves
# Game: 50 (38,179 Total Frames): Score: 260 Points, Final Epsilon: 0.60, Game Length: 1,181 Moves
# Game: 51 (38,963 Total Frames): Score: 140 Points, Final Epsilon: 0.59, Game Length: 784 Moves
# Game: 52 (39,634 Total Frames): Score: 150 Points, Final Epsilon: 0.58, Game Length: 671 Moves
# Game: 53 (40,462 Total Frames): Score: 210 Points, Final Epsilon: 0.57, Game Length: 828 Moves
# Game: 54 (41,277 Total Frames): Score: 155 Points, Final Epsilon: 0.55, Game Length: 815 Moves
# Game: 55 (42,228 Total Frames): Score: 480 Points, Final Epsilon: 0.54, Game Length: 951 Moves
# Game: 56 (42,850 Total Frames): Score: 110 Points, Final Epsilon: 0.53, Game Length: 622 Moves
# Game: 57 (43,359 Total Frames): Score: 75 Points, Final Epsilon: 0.53, Game Length: 509 Moves
# Game: 58 (44,193 Total Frames): Score: 35 Points, Final Epsilon: 0.51, Game Length: 834 Moves
# Game: 59 (44,811 Total Frames): Score: 80 Points, Final Epsilon: 0.50, Game Length: 618 Moves
# Game: 60 (45,603 Total Frames): Score: 165 Points, Final Epsilon: 0.49, Game Length: 792 Moves
# Game: 61 (46,723 Total Frames): Score: 590 Points, Final Epsilon: 0.48, Game Length: 1,120 Moves
# Game: 62 (47,276 Total Frames): Score: 75 Points, Final Epsilon: 0.47, Game Length: 553 Moves
# Game: 63 (48,061 Total Frames): Score: 155 Points, Final Epsilon: 0.46, Game Length: 785 Moves
# Game: 64 (49,059 Total Frames): Score: 500 Points, Final Epsilon: 0.44, Game Length: 998 Moves
# Game: 65 (50,279 Total Frames): Score: 415 Points, Final Epsilon: 0.43, Game Length: 1,220 Moves
# Game: 66 (51,285 Total Frames): Score: 205 Points, Final Epsilon: 0.41, Game Length: 1,006 Moves
# Game: 67 (51,705 Total Frames): Score: 75 Points, Final Epsilon: 0.41, Game Length: 420 Moves
# Game: 68 (52,517 Total Frames): Score: 150 Points, Final Epsilon: 0.39, Game Length: 812 Moves
# Game: 69 (53,515 Total Frames): Score: 365 Points, Final Epsilon: 0.38, Game Length: 998 Moves
# Game: 70 (54,031 Total Frames): Score: 65 Points, Final Epsilon: 0.37, Game Length: 516 Moves
# Game: 71 (54,504 Total Frames): Score: 70 Points, Final Epsilon: 0.37, Game Length: 473 Moves
# Game: 72 (55,411 Total Frames): Score: 350 Points, Final Epsilon: 0.35, Game Length: 907 Moves
# Game: 73 (56,373 Total Frames): Score: 410 Points, Final Epsilon: 0.34, Game Length: 962 Moves
# Game: 74 (57,433 Total Frames): Score: 425 Points, Final Epsilon: 0.32, Game Length: 1,060 Moves
# Game: 75 (58,004 Total Frames): Score: 110 Points, Final Epsilon: 0.32, Game Length: 571 Moves
# Game: 76 (59,120 Total Frames): Score: 290 Points, Final Epsilon: 0.30, Game Length: 1,116 Moves
# Game: 77 (59,714 Total Frames): Score: 90 Points, Final Epsilon: 0.29, Game Length: 594 Moves
# Game: 78 (60,695 Total Frames): Score: 320 Points, Final Epsilon: 0.28, Game Length: 981 Moves
# Game: 79 (61,110 Total Frames): Score: 50 Points, Final Epsilon: 0.27, Game Length: 415 Moves
# Game: 80 (61,780 Total Frames): Score: 115 Points, Final Epsilon: 0.26, Game Length: 670 Moves
# Game: 81 (62,247 Total Frames): Score: 105 Points, Final Epsilon: 0.26, Game Length: 467 Moves
# Game: 82 (63,358 Total Frames): Score: 285 Points, Final Epsilon: 0.24, Game Length: 1,111 Moves
# Game: 83 (63,868 Total Frames): Score: 75 Points, Final Epsilon: 0.23, Game Length: 510 Moves
# Game: 84 (64,597 Total Frames): Score: 320 Points, Final Epsilon: 0.22, Game Length: 729 Moves
# Game: 85 (65,211 Total Frames): Score: 40 Points, Final Epsilon: 0.21, Game Length: 614 Moves
# Game: 86 (66,224 Total Frames): Score: 285 Points, Final Epsilon: 0.20, Game Length: 1,013 Moves
# Game: 87 (66,990 Total Frames): Score: 225 Points, Final Epsilon: 0.19, Game Length: 766 Moves
# Game: 88 (67,452 Total Frames): Score: 55 Points, Final Epsilon: 0.18, Game Length: 462 Moves
# Game: 89 (68,290 Total Frames): Score: 290 Points, Final Epsilon: 0.17, Game Length: 838 Moves
# Game: 90 (69,513 Total Frames): Score: 460 Points, Final Epsilon: 0.15, Game Length: 1,223 Moves
# Game: 91 (70,169 Total Frames): Score: 95 Points, Final Epsilon: 0.14, Game Length: 656 Moves
# Game: 92 (71,107 Total Frames): Score: 175 Points, Final Epsilon: 0.13, Game Length: 938 Moves
# Game: 93 (71,889 Total Frames): Score: 160 Points, Final Epsilon: 0.12, Game Length: 782 Moves
# Game: 94 (73,040 Total Frames): Score: 305 Points, Final Epsilon: 0.10, Game Length: 1,151 Moves
# Game: 95 (73,687 Total Frames): Score: 105 Points, Final Epsilon: 0.10, Game Length: 647 Moves
# Game: 96 (74,412 Total Frames): Score: 210 Points, Final Epsilon: 0.10, Game Length: 725 Moves
# Game: 97 (74,947 Total Frames): Score: 90 Points, Final Epsilon: 0.10, Game Length: 535 Moves
# Game: 98 (75,748 Total Frames): Score: 85 Points, Final Epsilon: 0.10, Game Length: 801 Moves
# Game: 99 (76,650 Total Frames): Score: 95 Points, Final Epsilon: 0.10, Game Length: 902 Moves
# Game: 100 (77,701 Total Frames): Score: 185 Points, Final Epsilon: 0.10, Game Length: 1,051 Moves
# Game: 101 (78,311 Total Frames): Score: 70 Points, Final Epsilon: 0.10, Game Length: 610 Moves
# Game: 102 (79,033 Total Frames): Score: 230 Points, Final Epsilon: 0.10, Game Length: 722 Moves
# Game: 103 (79,606 Total Frames): Score: 130 Points, Final Epsilon: 0.10, Game Length: 573 Moves
# Game: 104 (80,148 Total Frames): Score: 20 Points, Final Epsilon: 0.10, Game Length: 542 Moves
# Game: 105 (80,875 Total Frames): Score: 170 Points, Final Epsilon: 0.10, Game Length: 727 Moves
# Game: 106 (81,683 Total Frames): Score: 90 Points, Final Epsilon: 0.10, Game Length: 808 Moves
# Game: 107 (82,296 Total Frames): Score: 245 Points, Final Epsilon: 0.10, Game Length: 613 Moves
# Game: 108 (82,919 Total Frames): Score: 165 Points, Final Epsilon: 0.10, Game Length: 623 Moves
# Game: 109 (84,230 Total Frames): Score: 350 Points, Final Epsilon: 0.10, Game Length: 1,311 Moves
# Game: 110 (84,894 Total Frames): Score: 160 Points, Final Epsilon: 0.10, Game Length: 664 Moves
# Game: 111 (85,299 Total Frames): Score: 5 Points, Final Epsilon: 0.10, Game Length: 405 Moves
# Game: 112 (85,950 Total Frames): Score: 115 Points, Final Epsilon: 0.10, Game Length: 651 Moves
# Game: 113 (86,911 Total Frames): Score: 355 Points, Final Epsilon: 0.10, Game Length: 961 Moves
# Game: 114 (87,887 Total Frames): Score: 455 Points, Final Epsilon: 0.10, Game Length: 976 Moves
# Game: 115 (88,865 Total Frames): Score: 200 Points, Final Epsilon: 0.10, Game Length: 978 Moves
# Game: 116 (89,742 Total Frames): Score: 355 Points, Final Epsilon: 0.10, Game Length: 877 Moves
# Game: 117 (90,188 Total Frames): Score: 50 Points, Final Epsilon: 0.10, Game Length: 446 Moves
# Game: 118 (91,228 Total Frames): Score: 250 Points, Final Epsilon: 0.10, Game Length: 1,040 Moves
# Game: 119 (91,838 Total Frames): Score: 90 Points, Final Epsilon: 0.10, Game Length: 610 Moves
# Game: 120 (92,780 Total Frames): Score: 150 Points, Final Epsilon: 0.10, Game Length: 942 Moves
# Game: 121 (93,175 Total Frames): Score: 50 Points, Final Epsilon: 0.10, Game Length: 395 Moves
# Game: 122 (93,983 Total Frames): Score: 140 Points, Final Epsilon: 0.10, Game Length: 808 Moves
# Game: 123 (94,522 Total Frames): Score: 40 Points, Final Epsilon: 0.10, Game Length: 539 Moves
# Game: 124 (95,637 Total Frames): Score: 185 Points, Final Epsilon: 0.10, Game Length: 1,115 Moves
# Game: 125 (96,585 Total Frames): Score: 295 Points, Final Epsilon: 0.10, Game Length: 948 Moves
# Game: 126 (97,583 Total Frames): Score: 390 Points, Final Epsilon: 0.10, Game Length: 998 Moves
# Game: 127 (98,299 Total Frames): Score: 75 Points, Final Epsilon: 0.10, Game Length: 716 Moves
# Game: 128 (98,745 Total Frames): Score: 50 Points, Final Epsilon: 0.10, Game Length: 446 Moves
# Game: 129 (99,651 Total Frames): Score: 200 Points, Final Epsilon: 0.10, Game Length: 906 Moves
# Game: 130 (100,337 Total Frames): Score: 70 Points, Final Epsilon: 0.10, Game Length: 686 Moves
# Game: 131 (100,862 Total Frames): Score: 55 Points, Final Epsilon: 0.10, Game Length: 525 Moves
# Game: 132 (101,473 Total Frames): Score: 90 Points, Final Epsilon: 0.10, Game Length: 611 Moves
# Game: 133 (102,502 Total Frames): Score: 290 Points, Final Epsilon: 0.10, Game Length: 1,029 Moves
# Game: 134 (103,609 Total Frames): Score: 535 Points, Final Epsilon: 0.10, Game Length: 1,107 Moves
# Game: 135 (104,101 Total Frames): Score: 65 Points, Final Epsilon: 0.10, Game Length: 492 Moves
# Game: 136 (104,775 Total Frames): Score: 120 Points, Final Epsilon: 0.10, Game Length: 674 Moves
# Game: 137 (105,609 Total Frames): Score: 110 Points, Final Epsilon: 0.10, Game Length: 834 Moves
# Game: 138 (106,583 Total Frames): Score: 120 Points, Final Epsilon: 0.10, Game Length: 974 Moves
# Game: 139 (107,018 Total Frames): Score: 60 Points, Final Epsilon: 0.10, Game Length: 435 Moves
# Game: 140 (108,286 Total Frames): Score: 550 Points, Final Epsilon: 0.10, Game Length: 1,268 Moves
# Game: 141 (108,841 Total Frames): Score: 140 Points, Final Epsilon: 0.10, Game Length: 555 Moves
# Game: 142 (109,721 Total Frames): Score: 235 Points, Final Epsilon: 0.10, Game Length: 880 Moves
# Game: 143 (110,424 Total Frames): Score: 45 Points, Final Epsilon: 0.10, Game Length: 703 Moves
# Game: 144 (111,090 Total Frames): Score: 55 Points, Final Epsilon: 0.10, Game Length: 666 Moves
# Game: 145 (111,784 Total Frames): Score: 100 Points, Final Epsilon: 0.10, Game Length: 694 Moves
# Game: 146 (112,728 Total Frames): Score: 185 Points, Final Epsilon: 0.10, Game Length: 944 Moves
# Game: 147 (113,511 Total Frames): Score: 145 Points, Final Epsilon: 0.10, Game Length: 783 Moves
# Game: 148 (114,271 Total Frames): Score: 180 Points, Final Epsilon: 0.10, Game Length: 760 Moves
# Game: 149 (115,255 Total Frames): Score: 290 Points, Final Epsilon: 0.10, Game Length: 984 Moves
# Game: 150 (116,191 Total Frames): Score: 240 Points, Final Epsilon: 0.10, Game Length: 936 Moves
# Game: 151 (116,843 Total Frames): Score: 185 Points, Final Epsilon: 0.10, Game Length: 652 Moves
# Game: 152 (117,684 Total Frames): Score: 145 Points, Final Epsilon: 0.10, Game Length: 841 Moves
# Game: 153 (118,324 Total Frames): Score: 110 Points, Final Epsilon: 0.10, Game Length: 640 Moves
# Game: 154 (120,099 Total Frames): Score: 635 Points, Final Epsilon: 0.10, Game Length: 1,775 Moves
# Game: 155 (121,158 Total Frames): Score: 410 Points, Final Epsilon: 0.10, Game Length: 1,059 Moves
# Game: 156 (121,860 Total Frames): Score: 65 Points, Final Epsilon: 0.10, Game Length: 702 Moves
# Game: 157 (122,380 Total Frames): Score: 105 Points, Final Epsilon: 0.10, Game Length: 520 Moves
# Game: 158 (123,059 Total Frames): Score: 20 Points, Final Epsilon: 0.10, Game Length: 679 Moves
# Game: 159 (124,230 Total Frames): Score: 600 Points, Final Epsilon: 0.10, Game Length: 1,171 Moves
# Game: 160 (124,634 Total Frames): Score: 75 Points, Final Epsilon: 0.10, Game Length: 404 Moves
# Game: 161 (125,781 Total Frames): Score: 220 Points, Final Epsilon: 0.10, Game Length: 1,147 Moves
# Game: 162 (126,582 Total Frames): Score: 130 Points, Final Epsilon: 0.10, Game Length: 801 Moves
# Game: 163 (127,477 Total Frames): Score: 185 Points, Final Epsilon: 0.10, Game Length: 895 Moves
# Game: 164 (128,353 Total Frames): Score: 210 Points, Final Epsilon: 0.10, Game Length: 876 Moves
# Game: 165 (128,913 Total Frames): Score: 55 Points, Final Epsilon: 0.10, Game Length: 560 Moves
# Game: 166 (129,895 Total Frames): Score: 265 Points, Final Epsilon: 0.10, Game Length: 982 Moves
# Game: 167 (131,449 Total Frames): Score: 680 Points, Final Epsilon: 0.10, Game Length: 1,554 Moves
# Game: 168 (132,673 Total Frames): Score: 160 Points, Final Epsilon: 0.10, Game Length: 1,224 Moves
# Game: 169 (133,297 Total Frames): Score: 70 Points, Final Epsilon: 0.10, Game Length: 624 Moves
# Game: 170 (134,309 Total Frames): Score: 780 Points, Final Epsilon: 0.10, Game Length: 1,012 Moves
# Game: 171 (135,133 Total Frames): Score: 230 Points, Final Epsilon: 0.10, Game Length: 824 Moves
# Game: 172 (135,775 Total Frames): Score: 95 Points, Final Epsilon: 0.10, Game Length: 642 Moves
# Game: 173 (136,900 Total Frames): Score: 245 Points, Final Epsilon: 0.10, Game Length: 1,125 Moves
# Game: 174 (137,841 Total Frames): Score: 180 Points, Final Epsilon: 0.10, Game Length: 941 Moves
# Game: 175 (139,740 Total Frames): Score: 550 Points, Final Epsilon: 0.10, Game Length: 1,899 Moves
# Game: 176 (140,692 Total Frames): Score: 470 Points, Final Epsilon: 0.10, Game Length: 952 Moves
# Game: 177 (142,142 Total Frames): Score: 700 Points, Final Epsilon: 0.10, Game Length: 1,450 Moves
# Game: 178 (143,201 Total Frames): Score: 210 Points, Final Epsilon: 0.10, Game Length: 1,059 Moves
# Game: 179 (143,595 Total Frames): Score: 30 Points, Final Epsilon: 0.10, Game Length: 394 Moves
# Game: 180 (144,573 Total Frames): Score: 185 Points, Final Epsilon: 0.10, Game Length: 978 Moves
# Game: 181 (144,990 Total Frames): Score: 30 Points, Final Epsilon: 0.10, Game Length: 417 Moves
# Game: 182 (145,601 Total Frames): Score: 30 Points, Final Epsilon: 0.10, Game Length: 611 Moves
# Game: 183 (146,258 Total Frames): Score: 75 Points, Final Epsilon: 0.10, Game Length: 657 Moves
# Game: 184 (147,092 Total Frames): Score: 135 Points, Final Epsilon: 0.10, Game Length: 834 Moves
# Game: 185 (147,992 Total Frames): Score: 390 Points, Final Epsilon: 0.10, Game Length: 900 Moves
# Game: 186 (148,676 Total Frames): Score: 105 Points, Final Epsilon: 0.10, Game Length: 684 Moves
# Game: 187 (149,381 Total Frames): Score: 135 Points, Final Epsilon: 0.10, Game Length: 705 Moves
# Game: 188 (150,624 Total Frames): Score: 315 Points, Final Epsilon: 0.10, Game Length: 1,243 Moves
# Game: 189 (151,992 Total Frames): Score: 445 Points, Final Epsilon: 0.10, Game Length: 1,368 Moves
# Game: 190 (153,002 Total Frames): Score: 235 Points, Final Epsilon: 0.10, Game Length: 1,010 Moves
# Game: 191 (154,293 Total Frames): Score: 355 Points, Final Epsilon: 0.10, Game Length: 1,291 Moves
# Game: 192 (154,822 Total Frames): Score: 125 Points, Final Epsilon: 0.10, Game Length: 529 Moves
# Game: 193 (156,055 Total Frames): Score: 270 Points, Final Epsilon: 0.10, Game Length: 1,233 Moves
# Game: 194 (156,903 Total Frames): Score: 120 Points, Final Epsilon: 0.10, Game Length: 848 Moves
# Game: 195 (157,896 Total Frames): Score: 240 Points, Final Epsilon: 0.10, Game Length: 993 Moves
# Game: 196 (158,703 Total Frames): Score: 195 Points, Final Epsilon: 0.10, Game Length: 807 Moves
# Game: 197 (159,216 Total Frames): Score: 45 Points, Final Epsilon: 0.10, Game Length: 513 Moves
# Game: 198 (159,742 Total Frames): Score: 105 Points, Final Epsilon: 0.10, Game Length: 526 Moves
# Game: 199 (160,379 Total Frames): Score: 105 Points, Final Epsilon: 0.10, Game Length: 637 Moves
# Game: 200 (161,631 Total Frames): Score: 435 Points, Final Epsilon: 0.10, Game Length: 1,252 Moves
# Game: 201 (162,185 Total Frames): Score: 75 Points, Final Epsilon: 0.10, Game Length: 554 Moves
# Game: 202 (162,592 Total Frames): Score: 30 Points, Final Epsilon: 0.10, Game Length: 407 Moves
# Game: 203 (163,505 Total Frames): Score: 200 Points, Final Epsilon: 0.10, Game Length: 913 Moves
# Game: 204 (164,458 Total Frames): Score: 315 Points, Final Epsilon: 0.10, Game Length: 953 Moves
# Game: 205 (164,958 Total Frames): Score: 35 Points, Final Epsilon: 0.10, Game Length: 500 Moves
# Game: 206 (165,479 Total Frames): Score: 60 Points, Final Epsilon: 0.10, Game Length: 521 Moves
# Game: 207 (166,205 Total Frames): Score: 115 Points, Final Epsilon: 0.10, Game Length: 726 Moves
# Game: 208 (166,839 Total Frames): Score: 150 Points, Final Epsilon: 0.10, Game Length: 634 Moves
# Game: 209 (167,651 Total Frames): Score: 180 Points, Final Epsilon: 0.10, Game Length: 812 Moves
# Game: 210 (168,332 Total Frames): Score: 55 Points, Final Epsilon: 0.10, Game Length: 681 Moves
# Game: 211 (168,839 Total Frames): Score: 60 Points, Final Epsilon: 0.10, Game Length: 507 Moves
# Game: 212 (170,103 Total Frames): Score: 280 Points, Final Epsilon: 0.10, Game Length: 1,264 Moves
# Game: 213 (170,753 Total Frames): Score: 105 Points, Final Epsilon: 0.10, Game Length: 650 Moves
# Game: 214 (171,115 Total Frames): Score: 65 Points, Final Epsilon: 0.10, Game Length: 362 Moves
# Game: 215 (171,944 Total Frames): Score: 175 Points, Final Epsilon: 0.10, Game Length: 829 Moves
# Game: 216 (172,467 Total Frames): Score: 70 Points, Final Epsilon: 0.10, Game Length: 523 Moves
# Game: 217 (173,432 Total Frames): Score: 145 Points, Final Epsilon: 0.10, Game Length: 965 Moves
# Game: 218 (173,967 Total Frames): Score: 50 Points, Final Epsilon: 0.10, Game Length: 535 Moves
# Game: 219 (174,465 Total Frames): Score: 55 Points, Final Epsilon: 0.10, Game Length: 498 Moves
# Game: 220 (175,501 Total Frames): Score: 230 Points, Final Epsilon: 0.10, Game Length: 1,036 Moves
# Game: 221 (176,373 Total Frames): Score: 245 Points, Final Epsilon: 0.10, Game Length: 872 Moves
# Game: 222 (177,189 Total Frames): Score: 180 Points, Final Epsilon: 0.10, Game Length: 816 Moves
# Game: 223 (178,215 Total Frames): Score: 345 Points, Final Epsilon: 0.10, Game Length: 1,026 Moves
# Game: 224 (178,910 Total Frames): Score: 150 Points, Final Epsilon: 0.10, Game Length: 695 Moves
# Game: 225 (179,451 Total Frames): Score: 60 Points, Final Epsilon: 0.10, Game Length: 541 Moves
# Game: 226 (180,254 Total Frames): Score: 235 Points, Final Epsilon: 0.10, Game Length: 803 Moves
# Game: 227 (181,219 Total Frames): Score: 195 Points, Final Epsilon: 0.10, Game Length: 965 Moves
# Game: 228 (182,165 Total Frames): Score: 130 Points, Final Epsilon: 0.10, Game Length: 946 Moves
# Game: 229 (183,328 Total Frames): Score: 210 Points, Final Epsilon: 0.10, Game Length: 1,163 Moves
# Game: 230 (184,203 Total Frames): Score: 95 Points, Final Epsilon: 0.10, Game Length: 875 Moves
# Game: 231 (185,168 Total Frames): Score: 200 Points, Final Epsilon: 0.10, Game Length: 965 Moves
# Game: 232 (185,804 Total Frames): Score: 125 Points, Final Epsilon: 0.10, Game Length: 636 Moves
# Game: 233 (186,853 Total Frames): Score: 175 Points, Final Epsilon: 0.10, Game Length: 1,049 Moves
# Game: 234 (187,392 Total Frames): Score: 55 Points, Final Epsilon: 0.10, Game Length: 539 Moves
# Game: 235 (188,031 Total Frames): Score: 100 Points, Final Epsilon: 0.10, Game Length: 639 Moves
# Game: 236 (188,685 Total Frames): Score: 80 Points, Final Epsilon: 0.10, Game Length: 654 Moves
# Game: 237 (189,700 Total Frames): Score: 335 Points, Final Epsilon: 0.10, Game Length: 1,015 Moves
# Game: 238 (190,786 Total Frames): Score: 185 Points, Final Epsilon: 0.10, Game Length: 1,086 Moves
# Game: 239 (191,935 Total Frames): Score: 600 Points, Final Epsilon: 0.10, Game Length: 1,149 Moves
# Game: 240 (192,610 Total Frames): Score: 110 Points, Final Epsilon: 0.10, Game Length: 675 Moves
# Game: 241 (193,306 Total Frames): Score: 160 Points, Final Epsilon: 0.10, Game Length: 696 Moves
# Game: 242 (194,227 Total Frames): Score: 190 Points, Final Epsilon: 0.10, Game Length: 921 Moves
# Game: 243 (195,826 Total Frames): Score: 505 Points, Final Epsilon: 0.10, Game Length: 1,599 Moves
# Game: 244 (196,686 Total Frames): Score: 215 Points, Final Epsilon: 0.10, Game Length: 860 Moves
# Game: 245 (197,564 Total Frames): Score: 50 Points, Final Epsilon: 0.10, Game Length: 878 Moves
# Game: 246 (198,184 Total Frames): Score: 45 Points, Final Epsilon: 0.10, Game Length: 620 Moves
# Game: 247 (199,122 Total Frames): Score: 225 Points, Final Epsilon: 0.10, Game Length: 938 Moves
# Game: 248 (199,780 Total Frames): Score: 110 Points, Final Epsilon: 0.10, Game Length: 658 Moves
# Game: 249 (200,746 Total Frames): Score: 230 Points, Final Epsilon: 0.10, Game Length: 966 Moves
#
# Training Time: 4:30:18.203856

# %%
# Set visualization defaults
plt.style.use('seaborn-darkgrid')

# Convert Loss History list to pandas series, calculate rolling averages (100, 1K frame intervals)
loss = pd.Series(loss_history)
rolling_mean_loss_100 = loss.rolling(100).mean()
rolling_mean_loss_1K = loss.rolling(1000).mean()

# Plot Learning Curve
fig = plt.figure()

ax = fig.add_subplot(111)

plt.plot(loss, label = 'Huber Loss')
plt.plot(rolling_mean_loss_100, label = 'Rolling Average (100 Training Steps)')
plt.plot(rolling_mean_loss_1K, label = 'Rolling Average (1,000 Training Steps)')

plt.title('DDQN Agent Learning Curve', fontweight = 'bold')

ax.set_xticklabels(['{:,.0f}'.format(TRAINING_START + x * TRAINING_FREQUENCY) for x in ax.get_xticks()])
plt.xlabel('Frames')
plt.ylabel('Huber Loss')

plt.legend()

# %%
# Plot Learning Curve
fig = plt.figure()

ax = fig.add_subplot(111)

clipped_loss = pd.Series(np.minimum(np.array(loss), 5 * np.ones(len(loss))))

rolling_mean_clipped_loss_100 = clipped_loss.rolling(100).mean()
rolling_mean_clipped_loss_1K = clipped_loss.rolling(1000).mean()

plt.plot(rolling_mean_clipped_loss_100, label = 'Rolling Average (100 Training Steps)')
plt.plot(rolling_mean_clipped_loss_1K, label = 'Rolling Average (1,000 Training Steps)')

plt.title('Deep-Q Network Learning Curve', fontweight = 'bold')

plt.xlabel('Frames')
plt.ylabel('Clipped Huber Loss')


plt.xlim(DECAY_STEPS, TOTAL_FRAMES/TRAINING_FREQUENCY)
ax.set_xticklabels(['{:,.0f}'.format(TRAINING_START + x * TRAINING_FREQUENCY) for x in ax.get_xticks()])

plt.legend()

plt.savefig(OUTPUT_DIR + 'Clipped Learning Curve.png')

# %%
# Calculate rolling game-score averages (At 10- and 25-Episode intervals)
rolling_mean_score_10 = pd.Series(run_dict['score']).rolling(10).mean()
rolling_mean_score_25 = pd.Series(run_dict['score']).rolling(25).mean()

# Plot Game Scoring Performance
fig = plt.figure()

ax = fig.add_subplot(111)

plt.plot(run_dict['game'], run_dict['score'], label = 'Game Score')
plt.plot(run_dict['game'], rolling_mean_score_10, label = 'Rolling Average (10 Games)')
plt.plot(run_dict['game'], rolling_mean_score_25, label = 'Rolling Average (25 Games)')

plt.title('DDQN Agent Scoring Performance', fontweight = 'bold')

plt.xlabel('Game')
plt.ylabel('Game Score')

plt.legend()

plt.savefig(OUTPUT_DIR + 'Scoring Curve.png')

# %%
# Calculate rolling game-length averages (At 10- and 25-Episode intervals)
rolling_mean_gl_10 = pd.Series(run_dict['length']).rolling(10).mean()
rolling_mean_gl_25 = pd.Series(run_dict['length']).rolling(25).mean()

# Plot Agent Survival Performance
fig = plt.figure()

ax = fig.add_subplot(111)

plt.plot(run_dict['game'], run_dict['length'], label = 'Game Length')
plt.plot(run_dict['game'], rolling_mean_gl_10, label = 'Rolling Average (10 Games)')
plt.plot(run_dict['game'], rolling_mean_gl_25, label = 'Rolling Average (25 Games)')

plt.title('DDQN Agent Survival Performance', fontweight = 'bold')

plt.xlabel('Game')
plt.ylabel('Game Length')

plt.legend()

# %%
agent.model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 22, 19, 32)        2080
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 8, 64)         32832
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 6, 64)          36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 3078
# =================================================================
# Total params: 1,648,294
# Trainable params: 1,648,294
# Non-trainable params: 0
# _________________________________________________________________
